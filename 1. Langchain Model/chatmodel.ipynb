# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = llm.invoke("What is the free tier of Google Gemini?")
dict(response)
# Out:
# {'content': 'The free tier of Google Gemini is essentially the **standard, widely available version of Gemini that you can access without any subscription fees.**\n\nHere\'s a breakdown of what that entails:\n\n*   **Access to Gemini Pro:** The primary model available in the free tier is **Gemini Pro**. This is a powerful and versatile model capable of handling a wide range of tasks, including:\n    *   Answering questions and providing information.\n    *   Generating creative text formats (poems, code, scripts, musical pieces, email, letters, etc.).\n    *   Summarizing text.\n    *   Translating languages.\n    *   Brainstorming ideas.\n    *   And much more.\n\n*   **How to Access It:**\n    *   **Web Interface:** The most common way to use the free tier is through the **Gemini web interface** (gemini.google.com). You can simply go to this website and start chatting with Gemini.\n    *   **Google AI Studio:** For developers who want to experiment and build with Gemini Pro, **Google AI Studio** offers a free tier with access to Gemini Pro through an API. This allows for more programmatic interaction.\n    *   **Google Workspace Integrations (Limited Free Access):** While many advanced Workspace integrations require a paid tier, some basic functionalities and access might be available within certain free Google Workspace plans, though this is less of a direct "Gemini free tier" and more about how Gemini is integrated.\n\n*   **What it\'s NOT:**\n    *   **Gemini Ultra:** The most advanced and capable model, **Gemini Ultra**, is **not** part of the free tier. It\'s available through the paid **Gemini Advanced** subscription.\n    *   **Dedicated or Priority Access:** As a free user, you might experience occasional slowdowns or limits during peak usage times, as paid users often get priority.\n    *   **Advanced Features:** Certain cutting-edge features or integrations that are still in development or require more processing power might be reserved for paid tiers.\n\n**In summary, the free tier of Google Gemini gives you access to the powerful Gemini Pro model through a user-friendly web interface and developer tools like Google AI Studio, allowing you to experience its capabilities without any cost.** It\'s a fantastic way to explore what Gemini can do for you.',
#  'additional_kwargs': {},
#  'response_metadata': {'finish_reason': 'STOP',
#   'model_name': 'gemini-2.5-flash-lite',
#   'safety_ratings': [],
#   'model_provider': 'google_genai'},
#  'type': 'ai',
#  'name': None,
#  'id': 'lc_run--019c3d41-dfd8-79f1-8507-2b0b014bd08b-0',
#  'tool_calls': [],
#  'invalid_tool_calls': [],
#  'usage_metadata': {'input_tokens': 10,
#   'output_tokens': 491,
#   'total_tokens': 501,
#   'input_token_details': {'cache_read': 0}}}

# %%
print(response.content)
# Out:
# The free tier of Google Gemini is essentially the **standard, widely available version of Gemini that you can access without any subscription fees.**
#
# Here's a breakdown of what that entails:
#
# *   **Access to Gemini Pro:** The primary model available in the free tier is **Gemini Pro**. This is a powerful and versatile model capable of handling a wide range of tasks, including:
#     *   Answering questions and providing information.
#     *   Generating creative text formats (poems, code, scripts, musical pieces, email, letters, etc.).
#     *   Summarizing text.
#     *   Translating languages.
#     *   Brainstorming ideas.
#     *   And much more.
#
# *   **How to Access It:**
#     *   **Web Interface:** The most common way to use the free tier is through the **Gemini web interface** (gemini.google.com). You can simply go to this website and start chatting with Gemini.
#     *   **Google AI Studio:** For developers who want to experiment and build with Gemini Pro, **Google AI Studio** offers a free tier with access to Gemini Pro through an API. This allows for more programmatic interaction.
#     *   **Google Workspace Integrations (Limited Free Access):** While many advanced Workspace integrations require a paid tier, some basic functionalities and access might be available within certain free Google Workspace plans, though this is less of a direct "Gemini free tier" and more about how Gemini is integrated.
#
# *   **What it's NOT:**
#     *   **Gemini Ultra:** The most advanced and capable model, **Gemini Ultra**, is **not** part of the free tier. It's available through the paid **Gemini Advanced** subscription.
#     *   **Dedicated or Priority Access:** As a free user, you might experience occasional slowdowns or limits during peak usage times, as paid users often get priority.
#     *   **Advanced Features:** Certain cutting-edge features or integrations that are still in development or require more processing power might be reserved for paid tiers.
#
# **In summary, the free tier of Google Gemini gives you access to the powerful Gemini Pro model through a user-friendly web interface and developer tools like Google AI Studio, allowing you to experience its capabilities without any cost.** It's a fantastic way to explore what Gemini can do for you.
